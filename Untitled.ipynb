# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("Birthweight_reduced_kg_R.csv")
df.head(100)
# Out:
#       ID  Length  Birthweight  Headcirc  Gestation  smoker  mage  mnocig  \
# 0   1360      56         4.55        34         44       0    20       0
# 1   1016      53         4.32        36         40       0    19       0
# 2    462      58         4.10        39         41       0    35       0
# 3   1187      53         4.07        38         44       0    20       0
# 4    553      54         3.94        37         42       0    24       0
# 5   1636      51         3.93        38         38       0    29       0
# 6    820      52         3.77        34         40       0    24       0
# 7   1191      53         3.65        33         42       0    21       0
# 8   1081      54         3.63        38         38       0    18       0
# 9    822      50         3.42        35         38       0    20       0
# 10  1683      53         3.35        33         41       0    27       0
# 11  1088      51         3.27        36         40       0    24       0
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Length', 'Birthweight', 'Headcirc', 'Gestation', 'smoker',
#        'mage', 'mnocig', 'mheight', 'mppwt', 'fage', 'fedyrs', 'fnocig',
#        'fheight', 'lowbwt', 'mage35'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID             0
# Length         0
# Birthweight    0
# Headcirc       0
# Gestation      0
# smoker         0
# mage           0
# mnocig         0
# mheight        0
# mppwt          0
# fage           0
# fedyrs         0
# fnocig         0
# fheight        0
# lowbwt         0
# mage35         0
# dtype: int64

# %%
X = df[['ID', 'Length', 'Headcirc', 'Gestation', 'smoker',
       'mage', 'mnocig', 'mheight', 'mppwt', 'fage', 'fedyrs', 'fnocig',
       'fheight', 'lowbwt', 'mage35']]
y = df['Birthweight']

# %%
X
# Out:
#       ID  Length  Headcirc  Gestation  smoker  mage  mnocig  mheight  mppwt  \
# 0   1360      56        34         44       0    20       0      162     57
# 1   1016      53        36         40       0    19       0      171     62
# 2    462      58        39         41       0    35       0      172     58
# 3   1187      53        38         44       0    20       0      174     68
# 4    553      54        37         42       0    24       0      175     66
# 5   1636      51        38         38       0    29       0      165     61
# 6    820      52        34         40       0    24       0      157     50
# 7   1191      53        33         42       0    21       0      165     61
# 8   1081      54        38         38       0    18       0      172     50
# 9    822      50        35         38       0    20       0      157     48
# 10  1683      53        33         41       0    27       0      164     62
# ...

# %%
y
# Out:
# 0     4.55
# 1     4.32
# 2     4.10
# 3     4.07
# 4     3.94
# 5     3.93
# 6     3.77
# 7     3.65
# 8     3.63
# 9     3.42
# 10    3.35
# 11    3.27
# 12    3.23
# 13    3.20
# 14    3.15
# 15    3.11
# 16    3.03
# 17    2.92
# 18    2.90
# 19    2.65
# 20    3.64
# 21    3.14
# 22    2.78
# 23    2.51
# 24    2.37
# 25    2.05
# 26    1.92
# 27    4.57
# 28    3.59
# 29    3.32
# 30    3.00
# 31    3.32
# 32    2.74
# 33    3.87
# 34    3.86
# 35    3.55
# 36    3.53
# 37    3.41
# 38    3.18
# 39    3.19
# 40    2.66
# 41    2.75
# Name: Birthweight, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#       ID  Length  Headcirc  Gestation  smoker  mage  mnocig  mheight  mppwt  \
# 9    822      50        35         38       0    20       0      157     48
# 15   321      48        33         37       0    28       0      158     54
# 33   223      50        33         45       1    28      25      163     54
# 16   697      48        35         39       0    27       0      162     62
# 36   365      52        37         40       1    26      25      170     62
# 35    27      53        37         41       1    37      25      161     66
# 0   1360      56        34         44       0    20       0      162     57
# 24  1363      48        30         37       1    20       7      163     47
# 5   1636      51        38         38       0    29       0      165     61
# 11  1088      51        36         40       0    24       0      168     53
# 40   516      47        33         35       1    20      35      170     57
# ...

# %%
X_test
# Out:
#       ID  Length  Headcirc  Gestation  smoker  mage  mnocig  mheight  mppwt  \
# 25   300      46        32         35       1    41       7      166     57
# 13   755      53        33         41       0    21       0      155     55
# 8   1081      54        38         38       0    18       0      172     50
# 26   431      48        30         33       1    20       7      161     50
# 4    553      54        37         42       0    24       0      175     66
# 39  1262      53        34         41       1    27      35      163     51
# 19  1313      43        32         33       0    24       0      149     45
# 29   752      49        36         40       1    27      12      152     48
# 30  1023      52        35         38       1    30      12      165     64
# 6    820      52        34         40       0    24       0      157     50
# 27  1764      58        39         41       1    32      12      173     70
# ...

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
accuracy = model.score(X_test, y_test)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.73

# %%
user_input = {
   'ID':300, 'Length':46, 'Headcirc':32,
    'Gestation':35, 'smoker':1,
       'mage':41, 'mnocig':7, 'mheight':166, 'mppwt':57, 'fage':37, 'fedyrs':14, 'fnocig':25,
       'fheight':173, 'lowbwt':1, 'mage35':1
}

# %%
import numpy as np

# Convert the user input dictionary to a 2D array
user_input_array = np.array([[user_input['ID'], user_input['Length'], user_input['Headcirc'], user_input['Gestation'], 
                              user_input['smoker'], user_input['mage'], user_input['mnocig'], user_input['mheight'], 
                              user_input['mppwt'], user_input['fage'], user_input['fedyrs'], user_input['fnocig'],
                              user_input['fheight'], user_input['lowbwt'], user_input['mage35']
                             ]])

# %%
user_input_array
# Out:
# array([[300,  46,  32,  35,   1,  41,   7, 166,  57,  37,  14,  25, 173,
#           1,   1]])

# %%
prediction = model.predict(user_input_array)

print(f'Predicted class: {prediction[0]}')

print(f'Predicted11 class: {prediction}')
# Out:
# Predicted class: 2.069963578696102
# Predicted11 class: [2.06996358]
# C:\Users\sanga\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
